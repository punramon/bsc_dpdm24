# %% [markdown]
# <a href="https://colab.research.google.com/github/punramon/bsc_dpdm24/blob/main/Chapter_2_Understanding_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import data from different formats

# %% [markdown]
# ### mount drive

# %%
# prompt: mount gdrive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## CSV

# %% [markdown]
# Expected problem: Encoding Error
#
# Solution: choose the **right** encoding in the read_csv()

# %%
# prompt: read csv file with pandas

import pandas as pd

# Assuming your CSV file is in the mounted drive
file_path = '/content/drive/MyDrive/bsc_dpdm24_data/tis_name_02122567.csv'

df = pd.read_csv(file_path, encoding='cp874')
df.head()
# Out:
#    ลำดับ    เลขที่ มอก.                                  ชื่อ มอก. ภาษาไทย  \
# 0      1         2-2525              ขวดแก้วสำหรับเครื่องดื่มประเภทอัดก๊าซ
# 1      2         3-2562                                             น้ำปลา
# 2      3  4 เล่ม 1-2558  หลอดไฟฟ้าไส้ทังสเตนสำหรับใช้ในที่อยู่อาศัยและท...
# 3      4  4 เล่ม 2-2552  วิธีมาตรฐานในการวัดอุณหภูมิที่เพิ่มขึ้นของขั้ว...
# 4      5  4 เล่ม 3-2563  หลอดไฟฟ้าไส้ทังสเตนสำหรับใช้ในที่อยู่อาศัยและท...
#
#                                 ชื่อ มอก. ภาษาอังกฤษ ประเภทมาตรฐาน  \
# 0                        Aerated water glass bottles        ทั่วไป
# 1                                         Fish sauce        ทั่วไป
# 2  Tungsten filament lamps for domestics and simi...        บังคับ
# 3  Standard method of measurement of lamp cap tem...        ทั่วไป
# 4  Tungsten filament lamps for domestics and simi...        ทั่วไป
#
#    กลุ่มผลิตภัณฑ์ ชนิดมาตรฐาน BCG Economy ประกาศกระทรวงฯ วันที่  \
# ...

# %% [markdown]
# ## Excel

# %% [markdown]
# Expected problem 1 : mutiple sheets

# %%
# prompt: open excel file for the sheet name

# Assuming your Excel file is in the mounted drive
excel_file_path = '/content/drive/MyDrive/bsc_dpdm24_data/export62_64.xlsx' #Replace with your file path

# Read the specified sheet into a DataFrame
try:
  df_excel = pd.read_excel(excel_file_path, sheet_name="Export 63")
  df_excel.head()  # จริง ๆ จบตรงนี้
except FileNotFoundError:
  print(f"Error: File not found at {excel_file_path}")
except ValueError:
  print(f"Error: Sheet sheet_name not found in the Excel file.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")

# %% [markdown]
# * try ไว้ลองทำกัน error (โปรแกรมมันจะปิด) --> ไปรัน except ให้ (คล้ายๆ if-else) - กรณีถ้ามัน error

# %%
df_excel.head()
# Out:
#    ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 0      2563            1              1022100          1               C62
# 1      2563            1              1022919          0               C62
# 2      2563            1              1022990          0               C62
# 3      2563            1              1023100          0               C62
# 4      2563            1              1023900          0               C62
#
#       คำอธิบายไทย                    คำอธิบาย  น้ำหนัก/ปริมาณสถิติ  \
# 0        โคตัวผู้                 Bullocks                   14736
# 1          อื่น ๆ                       Other                16995
# 2          อื่น ๆ                       Other                  261
# 3  สำหรับทำพันธุ์  Pure-bred breeding animals                 3460
# 4          อื่น ๆ                       Other                 1349
#
#    มูลค่าส่งออกเงินบาท
# 0            265002594
# 1            326112000
# 2              3444000
# ...

# %% [markdown]
# Expected problem 2 : table location (ไม่ได้เริ่มที่ 0 หรือที่ ๆ อ่านง่าย)

# %%
excel_file_path = '/content/drive/MyDrive/bsc_dpdm24_data/export62_64.xlsx' #Replace with your file path

# Read the specified sheet into a DataFrame
df_excel = pd.read_excel(excel_file_path, sheet_name="Export 64")
df_excel.head()
# Out:
#    Unnamed: 0 Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 0         NaN  Export 64          NaN                  NaN        NaN
# 1         NaN   ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ
# 2         NaN       2564            1             01012100        000
# 3         NaN       2564            1             01012900        000
# 4         NaN       2564            1             01022100        001
#
#           Unnamed: 5      Unnamed: 6                  Unnamed: 7  \
# 0                NaN             NaN                         NaN
# 1  หน่วยตามรหัสสถิติ     คำอธิบายไทย                    คำอธิบาย
# 2                C62  สำหรับทำพันธุ์  Pure-bred breeding animals
# 3                C62          อื่น ๆ                       Other
# 4                C62        โคตัวผู้                 Bullocks
#
#             Unnamed: 8           Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0                  NaN                  NaN          NaN          NaN
# ...

# %%
# prompt: open sheet number 3 of the excel file and select only the table part

from google.colab import drive
import pandas as pd

excel_file_path = '/content/drive/MyDrive/bsc_dpdm24_data/export62_64.xlsx'

try:
  # Open the third sheet (index 2)
  df_excel = pd.read_excel(excel_file_path, sheet_name=2)

  # Assuming the table starts from a specific row and column
  # Replace 'row_start' and 'column_start' with the actual row and column indices
  # where your table data begins (0-indexed)

  # Example (Adjust as needed)
  row_start = 2  # Start from row 3 (index 2)
  column_start = 0  # Start from column A (index 0)

  # Read the table data
  df_table = df_excel.iloc[row_start:, column_start:]

  df_table.head()


except FileNotFoundError:
  print(f"Error: File not found at {excel_file_path}")
except ValueError:
  print(f"Error: Sheet index 2 not found in the Excel file.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")

# %%
df_table.head() # ไม่ถูก
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 2         NaN       2564          1   01012100        000        C62
# 3         NaN       2564          1   01012900        000        C62
# 4         NaN       2564          1   01022100        001        C62
# 5         NaN       2564          1   01022919        000        C62
# 6         NaN       2564          1   01023100        000        C62
#
#        Unnamed: 6                  Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 2  สำหรับทำพันธุ์  Pure-bred breeding animals         44     196720
# 3          อื่น ๆ                       Other         35     182000
# 4        โคตัวผู้                 Bullocks          9674  145263681
# 5          อื่น ๆ                       Other      10976  199947461
# 6  สำหรับทำพันธุ์  Pure-bred breeding animals       3169   51784330
#
#    Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 2          NaN          NaN          NaN          NaN          NaN
# ...

# %%
excel_file_path = '/content/drive/MyDrive/bsc_dpdm24_data/export62_64.xlsx'
df_excel = pd.read_excel(excel_file_path, sheet_name="Export 64",skiprows=2) #ได้หัวตารางตามต้องการ
df_excel.head()
# Out:
#    Unnamed: 0  ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ  \
# 0         NaN      2564            1              1012100          0
# 1         NaN      2564            1              1012900          0
# 2         NaN      2564            1              1022100          1
# 3         NaN      2564            1              1022919          0
# 4         NaN      2564            1              1023100          0
#
#   หน่วยตามรหัสสถิติ     คำอธิบายไทย                    คำอธิบาย  \
# 0               C62  สำหรับทำพันธุ์  Pure-bred breeding animals
# 1               C62          อื่น ๆ                       Other
# 2               C62        โคตัวผู้                 Bullocks
# 3               C62          อื่น ๆ                       Other
# 4               C62  สำหรับทำพันธุ์  Pure-bred breeding animals
#
#    น้ำหนัก/ปริมาณสถิติ  มูลค่าส่งออกเงินบาท  Unnamed: 10  Unnamed: 11  \
# 0                   44               196720          NaN          NaN
# ...

# %%
df_excel = pd.read_excel(excel_file_path, sheet_name="Export 64",skiprows=2,usecols=[1,2,3,4]) # จะเอาตั้งแต่ column ไหน --> ใส่ list range
df_excel.head()
# Out:
#    ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ
# 0      2564            1              1012100          0
# 1      2564            1              1012900          0
# 2      2564            1              1022100          1
# 3      2564            1              1022919          0
# 4      2564            1              1023100          0

# %%
df_excel = pd.read_excel(excel_file_path, sheet_name="Export 64",skiprows=2,usecols=range(1,10)) # จะเอาตั้งแต่ column ไหน --> ใส่ range
df_excel.head()
# Out:
#    ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 0      2564            1              1012100          0               C62
# 1      2564            1              1012900          0               C62
# 2      2564            1              1022100          1               C62
# 3      2564            1              1022919          0               C62
# 4      2564            1              1023100          0               C62
#
#       คำอธิบายไทย                    คำอธิบาย  น้ำหนัก/ปริมาณสถิติ  \
# 0  สำหรับทำพันธุ์  Pure-bred breeding animals                   44
# 1          อื่น ๆ                       Other                   35
# 2        โคตัวผู้                 Bullocks                    9674
# 3          อื่น ๆ                       Other                10976
# 4  สำหรับทำพันธุ์  Pure-bred breeding animals                 3169
#
#    มูลค่าส่งออกเงินบาท
# 0               196720
# 1               182000
# 2            145263681
# ...

# %%
df_excel.tail()
# Out:
#       ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 1373      2564            1             25309090          5               KGM
# 1374      2564            1             25309090         90               KGM
# 1375      2564            1             26011110          0               KGM
# 1376      2564            1             26011190          0               KGM
# 1377      2564            1             26011290          0               KGM
#
#                คำอธิบายไทย                    คำอธิบาย  น้ำหนัก/ปริมาณสถิติ  \
# 1373        แร่ไพโรฟิลไรท์                 Pyrophylite               272000
# 1374                อื่น ๆ                       Other              2109246
# 1375  แร่เฮมาไทต์และหัวแร่  Haematite and concentrates             42930945
# 1376                อื่น ๆ                       Other                    5
# 1377                อื่น ๆ                       Other                   70
#
#       มูลค่าส่งออกเงินบาท
# ...

# %% [markdown]
# ## Google Sheets

# %%
# prompt: open google sheets

from google.colab import auth
auth.authenticate_user() # This line initiates authentication within the Colab environment.
# If prompted, follow the instructions to authorize access to your Google account.

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds) # This line uses the obtained credentials to authorize gspread.

# Open the Google Sheet by its key
spreadsheet_key = '1VAoow1EyrTc7WriK9qApmQ6G_YDk_xLJVIQh3BU3U5U'  # '@param' เขียนติดใน#ไม่ใส่่''จะเป็นใส่ input
#key --> copy ตัวหลัง d/ อันค่าแปลก ๆ อะ
sh = gc.open_by_key(spreadsheet_key)

worksheet_name = "Export 62"
worksheet = sh.worksheet(worksheet_name)

data = worksheet.get_all_values()
df_sheets = pd.DataFrame(data[1:], columns=data[0])
df_sheets.head()
# Out:
#   ปีแม่แบบ เดือนแม่แบบ พิกัดศุลกากร 8 หลัก รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 0     2562           1            01012900       000               C62
# 1     2562           1            01022100       001               C62
# 2     2562           1            01022100       002               C62
# 3     2562           1            01022919       000               C62
# 4     2562           1            01023100       000               C62
#
#       คำอธิบายไทย                    คำอธิบาย น้ำหนัก/ปริมาณสถิติ  \
# 0          อื่น ๆ                       Other                   7
# 1        โคตัวผู้                 Bullocks                   6663
# 2       โคตัวเมีย                        Cows                  36
# 3          อื่น ๆ                       Other               16983
# 4  สำหรับทำพันธุ์  Pure-bred breeding animals                 746
#
#   มูลค่าส่งออกเงินบาท
# 0              105000
# 1           119934000
# 2             2223000
# 3           362443500
# 4            13055000

# %% [markdown]
# ## JSON

# %% [markdown]
# โหลดได้ 2 แบบ
# 1. แบบตารางเลย - รู้ว่าเป็น list
# 2. ใช้ load json

# %% [markdown]
# * เป็น dict อ่านได้ง่าย
#
# * ใส่ตารางซ้อนตารางได้
# * มี list ย่อยได้
# > in vscode can use > json viewer ดูความซับซ้อนได้

# %%
# prompt: load JSON file name data_station from the drive

# Assuming your JSON file is in the mounted drive
json__file_path = '/content/drive/MyDrive/bsc_dpdm24_data/data_station.json'  # Replace with the actual path

df_json = pd.read_json(json__file_path)
df_json.head()
# Out:
#    id  station_code           name            en_name th_short en_short  \
# 0   1          1001        กรุงเทพ            Bangkok      กท.      BKK
# 1   2          1002          ยมราช           Yommaraj      ยช.      YMR
# 2   3          1004         สามเสน            Sam Sen      สส.      SAM
# 3   4          1006     ประดิพัทธ์          Pra Dipat     ปอิ.      PDP
# 4   5          1007  ชุมทางบางซื่อ  Bang Sue Junction      บซ.      BSJ
#
#   chname  controldivision  exact_km  exact_distance  km  class        lat  \
# 0     曼谷               14         0               0   0     11  13.739277
# 1    勇马拉               14         2               2   2     99          0
# 2     三森               14         5               4   4      1  13.779293
# 3    帕涤潘               14         6               6   6     99          0
# 4   邦苏总站               14         7               7   7      1    13.8043
#
#          long  active  giveway  dual_track  comment
# ...

# %% [markdown]
# > กรณีซับซ้อนขึ้น เช่น หลายคำร้องซ้อนกัน

# %%
json__file_path = '/content/drive/MyDrive/bsc_dpdm24_data/memo_2298.json'  # Replace with the actual path

df_json = pd.read_json(json__file_path)
df_json.head() # vscode อ่านได้ 1 แต่  python อ่านได้ 2
# Out:
#    MemoId       DocumentNo  TemplateId            TemplateName  \
# 0    2298  REQ-2019-002298        1050  แบบฟอร์มเบิกเงินสดย่อย
# 1    2298  REQ-2019-002298        1050  แบบฟอร์มเบิกเงินสดย่อย
#
#                        ToPerson                   CcPerson  CreatorId  \
# 0  Mr. Suwittawat Ragsameorwong  Miss Soravee Ritgarunvong          8
# 1  Mr. Suwittawat Ragsameorwong  Miss Soravee Ritgarunvong          8
#
#                        CNameTh                     CNameEn  CPositionId  ...  \
# 0  นางสาวเพิ่มสิน คุณวิสิฏสิริ  Miss Phoemsin Kunwisitsiri           16  ...
# 1  นางสาวเพิ่มสิน คุณวิสิฏสิริ  Miss Phoemsin Kunwisitsiri           16  ...
#
#   Amount               RequestDate              ModifiedDate PersonWaitingId  \
# 0    300  2019-03-21T08:43:47.490Z  2019-03-22T12:03:23.447Z             NaN
# 1    300  2019-03-21T08:43:47.490Z  2019-03-22T12:03:23.447Z             NaN
#
#               PersonWaiting  CompanyId         CompanyName  CompletedDate  \
# ...

# %% [markdown]
# * ถ้าอยากจัดการข้อมูลจริง ๆ --> use lib json

# %%
import json
f = open('/content/drive/MyDrive/bsc_dpdm24_data/memo_2298.json')
json_2298 = json.load(f)
f.close()

# %%
json_2298
# Out:
# {'MemoId': 2298,
#  'DocumentNo': 'REQ-2019-002298',
#  'TemplateId': 1050,
#  'TemplateName': 'แบบฟอร์มเบิกเงินสดย่อย',
#  'ToPerson': 'Mr. Suwittawat Ragsameorwong',
#  'CcPerson': 'Miss Soravee Ritgarunvong',
#  'CreatorId': 8,
#  'CNameTh': 'นางสาวเพิ่มสิน คุณวิสิฏสิริ',
#  'CNameEn': 'Miss Phoemsin Kunwisitsiri',
#  'CPositionId': 16,
#  'CPositionTh': 'ผู้จัดการฝ่ายขาย',
#  'CPositionEn': 'Account Manager',
#  'CDepartmentId': 4,
#  'CDepartmentTh': 'Management',
#  'CDepartmentEn': 'Management',
#  'CDivisionId': None,
#  'CDivisionTh': None,
#  'CDivisionEn': None,
#  'RequesterId': 8,
#  'RNameTh': 'นางสาวเพิ่มสิน คุณวิสิฏสิริ',
#  'RNameEn': 'Miss Phoemsin Kunwisitsiri',
#  'RPositionId': 16,
#  'RPositionTh': 'ผู้จัดการฝ่ายขาย',
#  'RPositionEn': 'Account Manager',
#  'RDepartmentId': 4,
#  'RDepartmentTh': 'Management',
#  'RDepartmentEn': 'Management',
#  'RDivisionId': None,
#  'RDivisionTh': None,
#  'RDivisionEn': None,
#  'MemoSubject': 'เบิกเงินสดย่อย',
# ...

# %%
# อยากตึง StatusName
json_2298['StatusName']
# Out:
# 'Rejected'

# %% [markdown]
# # Quiz 3

# %%
# ดึงข้อมูลจาก ActionHistory ที่ ActionProcess = 'submit'
for action in json_2298['ActionHistory']:
    if action['ActionProcess'] == 'submit':
        actor_name = action['ActorName']
        action_process = action['ActionProcess']
        print(f"ActorName: {actor_name}, ActionProcess: {action_process}")
# Out:
# ActorName: นางสาวเพิ่มสิน คุณวิสิฏสิริ, ActionProcess: submit

# %% [markdown]
# # Distance

# %% [markdown]
# # Normalization (Z-score & Min-Max normalization)
